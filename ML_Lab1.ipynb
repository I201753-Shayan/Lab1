# %% [markdown]
# # ML-Lab Task 01: K-folds
# ## Name: Shayan Bakht
# ## Roll-number:20I-1753
# ## AI-K

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv("ECG200_TRAIN.csv", delimiter="  ")
df
# Out:
# C:\Users\Xade\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#     -1.0000000e+00   5.0205548e-01   5.4216265e-01   7.2238348e-01  \
# 0              1.0        0.147647        0.804668        0.367771
# 1             -1.0        0.316646        0.243199        0.370471
# 2             -1.0        1.168874        2.075901        1.760141
# 3              1.0        0.648658        0.752026        2.636231
# 4              1.0        0.404733        1.280859        2.515148
# ..             ...             ...             ...             ...
# 94             1.0        0.581277        0.876188        1.042767
# 95            -1.0        2.689017        2.708703        2.008381
# ...

# %% [markdown]
# # creating 4 dfs for k folds

# %%
sorted_df = df.sort_values(by='-1.0000000e+00',ignore_index=True)
sorted_df
# Out:
#     -1.0000000e+00   5.0205548e-01   5.4216265e-01   7.2238348e-01  \
# 0             -1.0        0.992927        2.322843        2.350584
# 1             -1.0        0.467379        0.340104        0.351390
# 2             -1.0        0.187534       -0.276638       -0.308805
# 3             -1.0        0.203040        0.462079        0.748368
# 4             -1.0        0.123776        2.433461        2.762385
# ..             ...             ...             ...             ...
# 94             1.0        0.188247        0.540119        2.178449
# 95             1.0        1.257138        2.780970        3.287135
# 96             1.0        0.656567        2.439455        3.768696
# 97             1.0        0.642756        1.965222        2.904762
# 98             1.0        0.073124        0.776054        2.181336
#
#      1.4288852e+00   2.1365158e+00   2.2811490e+00   1.9362737e+00  \
# 0         2.580396        2.635011        1.467424       -0.128954
# ...

# %%
negative_Values = sorted_df[:30]

# %%
#negative_Values

# %%
positive_Values = sorted_df[30:]
#positive_Values

# %%
n1 = negative_Values[0:7]
p1 = positive_Values[0:17]
DF1 = pd.concat([n1,p1],axis=0)
DF1=DF1.sample(frac=1)
#DF1

# %%
n2 = negative_Values [7:14]
p2 = positive_Values [17:34]
DF2 = pd.concat([n2,p2],axis=0)
DF2=DF2.sample(frac=1)
#DF2

# %%
n3 = negative_Values [14:21]
p3 = positive_Values [34:51]
DF3 = pd.concat([n3,p3],axis=0)
DF3=DF3.sample(frac=1)
#DF3

# %%
n4 = negative_Values [21:28]
p4 = positive_Values [51:68]
DF4 = pd.concat([n4,p4],axis=0)
DF4=DF4.sample(frac=1)
#DF4

# %% [markdown]
# # First Model
# ## Test = DF1
# ## Train = DF2,DF3,DF4

# %%
Accurices = []

# %%
train = pd.concat([DF2,DF3],axis=0)
train = pd.concat([train,DF4],axis=0)
train = train.sample(frac=1)
#train
test = DF1

# %%
x_train = train.drop('-1.0000000e+00',axis=1)
y_train = train["-1.0000000e+00"]

x_test = test.drop('-1.0000000e+00',axis=1)
y_test = test["-1.0000000e+00"]

# %%
knn = KNeighborsClassifier(n_neighbors = 3) 
knn.fit(x_train, y_train)
pred = knn.predict(x_test)

score = knn.score(x_test, y_test)
Accurices.append(score)
print(score)
print(classification_report(y_test, pred))
# Out:
# 0.8333333333333334
#               precision    recall  f1-score   support
#
#         -1.0       0.67      0.86      0.75         7
#          1.0       0.93      0.82      0.87        17
#
#     accuracy                           0.83        24
#    macro avg       0.80      0.84      0.81        24
# weighted avg       0.86      0.83      0.84        24

# %% [markdown]
# # Second Model
# ## Test = DF2
# ## Train = DF1,DF3,DF4

# %%
train = pd.concat([DF1,DF3],axis=0)
train = pd.concat([train,DF4],axis=0)
train = train.sample(frac=1)
#train
test = DF2

# %%
x_train = train.drop('-1.0000000e+00',axis=1)
y_train = train["-1.0000000e+00"]

x_test = test.drop('-1.0000000e+00',axis=1)
y_test = test["-1.0000000e+00"]

# %%
knn = KNeighborsClassifier(n_neighbors = 3) 
knn.fit(x_train, y_train)
pred = knn.predict(x_test)

score = knn.score(x_test, y_test)
Accurices.append(score)
print(score)
print(classification_report(y_test, pred))
# Out:
# 0.9166666666666666
#               precision    recall  f1-score   support
#
#         -1.0       1.00      0.71      0.83         7
#          1.0       0.89      1.00      0.94        17
#
#     accuracy                           0.92        24
#    macro avg       0.95      0.86      0.89        24
# weighted avg       0.93      0.92      0.91        24

# %% [markdown]
# # Third Model
# ## Test = DF3
# ## Train = DF1,DF2,DF4

# %%
train = pd.concat([DF1,DF2],axis=0)
train = pd.concat([train,DF4],axis=0)
train = train.sample(frac=1)
#train
test = DF3

# %%
x_train = train.drop('-1.0000000e+00',axis=1)
y_train = train["-1.0000000e+00"]

x_test = test.drop('-1.0000000e+00',axis=1)
y_test = test["-1.0000000e+00"]

# %%
knn = KNeighborsClassifier(n_neighbors = 3) 
knn.fit(x_train, y_train)
pred = knn.predict(x_test)

score = knn.score(x_test, y_test)
Accurices.append(score)
print(score)
print(classification_report(y_test, pred))
# Out:
# 0.875
#               precision    recall  f1-score   support
#
#         -1.0       1.00      0.57      0.73         7
#          1.0       0.85      1.00      0.92        17
#
#     accuracy                           0.88        24
#    macro avg       0.93      0.79      0.82        24
# weighted avg       0.89      0.88      0.86        24

# %% [markdown]
# # Fourth Model
# ## Test = DF4
# ## Train = DF1,DF2,DF3

# %%
train = pd.concat([DF1,DF2],axis=0)
train = pd.concat([train,DF3],axis=0)
train = train.sample(frac=1)
#train
test = DF4

# %%
x_train = train.drop('-1.0000000e+00',axis=1)
y_train = train["-1.0000000e+00"]

x_test = test.drop('-1.0000000e+00',axis=1)
y_test = test["-1.0000000e+00"]

# %%
knn = KNeighborsClassifier(n_neighbors = 3) 
knn.fit(x_train, y_train)
pred = knn.predict(x_test)

score = knn.score(x_test, y_test)
Accurices.append(score)
print(score)
print(classification_report(y_test, pred))
# Out:
# 0.875
#               precision    recall  f1-score   support
#
#         -1.0       0.83      0.71      0.77         7
#          1.0       0.89      0.94      0.91        17
#
#     accuracy                           0.88        24
#    macro avg       0.86      0.83      0.84        24
# weighted avg       0.87      0.88      0.87        24

# %% [markdown]
# ## Calculating the mean of the 4 accuries

# %%
avg_accuracy = 0
for i in  Accurices:
    avg_accuracy = avg_accuracy + i
avg_accuracy = avg_accuracy / 4
avg_accuracy
# Out:
# 0.875

# %% [markdown]
# ### The average accurcy of the model trained on data which was manually splitted is the above

# %% [markdown]
# # Comparing our results with sklearns results

# %%
from sklearn.model_selection import cross_val_score

# %%
X = df.drop('-1.0000000e+00',axis=1)
y = df["-1.0000000e+00"]

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
CV_Accuricies = cross_val_score(knn, X, y, cv=4, scoring='accuracy')
CV_Accuricies = CV_Accuricies.mean()
print(CV_Accuricies)
# Out:
# 0.89875

# %%
print("Conclusion/Report")
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("Average of manual accuracy: ",avg_accuracy)
print("Accuracy of train_test_split: ",CV_Accuricies)
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("Difference: ", CV_Accuricies-avg_accuracy)
# Out:
# Conclusion/Report
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Average of manual accuracy:  0.875
# Accuracy of train_test_split:  0.89875
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Difference:  0.02375000000000005
